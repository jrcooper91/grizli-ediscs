# %%
run ediscs_gprior-env.py

# %% [markdown]
# # HST Cycle 20 Matched to LDP with gaussian prior, SN_Ha >5, quality cuts, all m

# %% [markdown]
# # UVJ

# %%
uvj(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %% [markdown]
# # SF Fractions:

# %% [markdown]
# ## Clusters 89%
# ## Field       89%
# ## Core       100%
# ## Groups  82%

# %%
cf_Ha    = [] 
crf_VJ   = []
crf_UV   = []
crf_m    = []
cz       = []
gf_Ha    = [] 
grf_VJ   = []
grf_UV   = []
grf_m    = []
gz       = []
