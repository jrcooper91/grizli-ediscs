# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sig = 0.007
z_LDP = 0 #example
z = np.arange(-2,2,.001)
p_z = np.exp(-(z - z_LDP)**2/(2*sig**2))/((2*np.pi)**0.5/sig)
plt.xlim(-0.5,0.5)
plt.title('single gaussian')
plt.plot(z,p_z)

# %%
sig = 0.007
z_LDP = 0 #example
z = np.arange(-2,2,.001)
p_z_main = 0.95*np.exp(-(z - z_LDP)**2/(2*sig**2))/((2*np.pi)**0.5/sig)
p_z_side = 0.05*np.exp(-(z - z_LDP + 0.1)**2/(2*sig**2))/((2*np.pi)**0.5/sig)
plt.xlim(-0.5,0.5)
plt.title('double gaussian')
plt.plot(z,p_z_main+p_z_side)
