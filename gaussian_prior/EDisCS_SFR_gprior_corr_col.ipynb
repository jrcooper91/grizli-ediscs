# %%
run ediscs_gprior-test.py

# %% [markdown]
# # HST Cycle 20 Matched to LDP with gaussian prior & SN_Ha >5

# %% [markdown]
# # 1301-1139 z = 0.4828

# %%
c1301(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %% [markdown]
# # 1059-1253 z = 0.4564

# %%
c1059(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %% [markdown]
# # 1138-1133 z = 0.4796

# %%
c1138(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %% [markdown]
# # 1227-1138 z = 0.6357

# %%
c1227(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %%
#SFR_SN(cf_Ha,gf_Ha,crf_VJ,crf_UV,crf_m,cz)

# %% [markdown]
# # SF Fractions:

# %% [markdown]
# ## Clusters 89%
# ## Field       87%
# ## Core       100%
# ## Groups  82%

# %% [markdown]
# # Offsets used:
#
# ### 1138: (0.3,0.3)
# ### 1227: (-0.1,0.3)
# ### 1301: (0,0)

# %%
cf_Ha    = [] 
crf_VJ   = []
crf_UV   = []
crf_m    = []
cz       = []
gf_Ha    = [] 
grf_VJ   = []
grf_UV   = []
grf_m    = []
gz       = []
