# %%
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import astropy 
from astropy import cosmology
from astropy.cosmology import WMAP9 as cosmo
import math as mt
import os, sys
import matplotlib.lines as mlines

# %%
plt.figure(figsize=(5,5), dpi= 80, facecolor='w', edgecolor='k')
f = open('/Users/jennifercooper/Projects/thesis/WFI_catalogs/1227_clz.txt', 'r')
lines = f.readlines()[1:]
f.close()
    
#create arrays 
ra    = [] 
dec   = []

  
    
    #pull array column 
for line in lines: 
    a = line.split()
    ra.append(float(a[1]))
    dec.append(float(a[2]))
    
a = [186.95,187]
b = [-11.68,-11.68]
c = [-11.63,-11.63]
d = [-11.68,-11.63]
e = [186.95,186.95]
f = [187,187]

a1 = [186.97,187.02]
b1 = [-11.57,-11.57]
c1 = [-11.62,-11.62]
d1 = [-11.57,-11.62]
e1 = [186.97,186.97]
f1 = [187.02,187.02]

a2 = [187.04,187.09]
b2 = [-11.55,-11.55]
c2 = [-11.5,-11.5]
d2 = [-11.55,-11.5]
e2 = [187.04,187.04]
f2 = [187.09,187.09]




ra = np.array(ra)
dec = np.array(dec)
sns.kdeplot(ra, dec, cmap="Blues", shade=True, shade_lowest=True)
plt.title('1227')
plt.plot(a,c,color='black')
plt.plot(a,b,color='black')
plt.plot(e,d,color='black')
plt.plot(f,d,color='black')
plt.plot(a1,c1,color='black')
plt.plot(a1,b1,color='black')
plt.plot(e1,d1,color='black')
plt.plot(f1,d1,color='black')
plt.plot(a2,c2,color='black')
plt.plot(a2,b2,color='black')
plt.plot(e2,d2,color='black')
plt.plot(f2,d2,color='black')
plt.xlim(186.6,187.3)
plt.ylim(-11.9,-11.3)
plt.show()

# %%
plt.figure(figsize=(15,15), dpi= 80, facecolor='w', edgecolor='k')



plt.subplot(3,2,1)


f = open('/Users/jennifercooper/Projects/thesis/WFI_catalogs/1138_clz.txt', 'r')
lines = f.readlines()[1:]
f.close()
    
#create arrays 
ra    = [] 
dec   = []

  
    
    #pull array column 
for line in lines: 
    a = line.split()
    ra.append(float(a[1]))
    dec.append(float(a[2]))

        
ra = np.array(ra)
dec = np.array(dec)

a = [174.36,174.41]
b = [-11.45,-11.45]
c = [-11.4,-11.4]
d = [-11.45,-11.4]
e = [174.36,174.36]
f = [174.41,174.41]

a1 = [174.67,174.72]
b1 = [-11.55,-11.55]
c1 = [-11.6,-11.6]
d1 = [-11.55,-11.6]
e1 = [174.67,174.67]
f1 = [174.72,174.72]

a2 = [174.54,174.59]
b2 = [-11.59,-11.59]
c2 = [-11.54,-11.54]
d2 = [-11.59,-11.54]
e2 = [174.54,174.54]
f2 = [174.59,174.59]

circle1 = plt.Circle((174.55, -11.55), 0.055, color='r', fill=False)


sns.kdeplot(ra, dec, cmap="Blues", shade=True, shade_lowest=True)
plt.gcf().gca().add_artist(circle1)


plt.plot(a,c,color='black')
plt.plot(a,b,color='black')
plt.plot(e,d,color='black')
plt.plot(f,d,color='black')
plt.plot(a1,c1,color='black')
plt.plot(a1,b1,color='black')
plt.plot(e1,d1,color='black')
plt.plot(f1,d1,color='black')
plt.plot(a2,c2,color='black')
plt.plot(a2,b2,color='black')
plt.plot(e2,d2,color='black')
plt.plot(f2,d2,color='black')

plt.xlim(174.2,174.9)
plt.ylim(-11.2,-11.9)
plt.title('1138')
plt.subplot(3,2,2)

f = open('/Users/jennifercooper/Projects/thesis/WFI_catalogs/1227_clz.txt', 'r')
lines = f.readlines()[1:]
f.close()
    
#create arrays 
ra    = [] 
dec   = []

  
    
    #pull array column 
for line in lines: 
    a = line.split()
    ra.append(float(a[1]))
    dec.append(float(a[2]))
    
a = [186.95,187]
b = [-11.68,-11.68]
c = [-11.63,-11.63]
d = [-11.68,-11.63]
e = [186.95,186.95]
f = [187,187]

a1 = [186.97,187.02]
b1 = [-11.57,-11.57]
c1 = [-11.62,-11.62]
d1 = [-11.57,-11.62]
e1 = [186.97,186.97]
f1 = [187.02,187.02]

a2 = [187.04,187.09]
b2 = [-11.55,-11.55]
c2 = [-11.5,-11.5]
d2 = [-11.55,-11.5]
e2 = [187.04,187.04]
f2 = [187.09,187.09]


ra = np.array(ra)
dec = np.array(dec)

circle1 = plt.Circle((186.99, -11.59), 0.035, color='r', fill=False)


sns.kdeplot(ra, dec, cmap="Blues", shade=True, shade_lowest=True)
plt.gcf().gca().add_artist(circle1)


plt.title('1227')
plt.plot(a,c,color='black')
plt.plot(a,b,color='black')
plt.plot(e,d,color='black')
plt.plot(f,d,color='black')
plt.plot(a1,c1,color='black')
plt.plot(a1,b1,color='black')
plt.plot(e1,d1,color='black')
plt.plot(f1,d1,color='black')
plt.plot(a2,c2,color='black')
plt.plot(a2,b2,color='black')
plt.plot(e2,d2,color='black')
plt.plot(f2,d2,color='black')
plt.xlim(186.6,187.3)
plt.ylim(-11.9,-11.3)
plt.subplot(3,2,3)

f = open('/Users/jennifercooper/Projects/thesis/WFI_catalogs/1301_clz.txt', 'r')
lines = f.readlines()[1:]
f.close()
    
#create arrays 
ra    = [] 
dec   = []

  
    
    #pull array column 
for line in lines: 
    a = line.split()
    ra.append(float(a[1]))
    dec.append(float(a[2]))

        
ra = np.array(ra)
dec = np.array(dec)

a = [195.23,195.28]
b = [-11.55,-11.55]
c = [-11.5,-11.5]
d = [-11.55,-11.5]
e = [195.23,195.23]
f = [195.28,195.28]

a1 = [195.33,195.38]
b1 = [-11.53,-11.53]
c1 = [-11.58,-11.58]
d1 = [-11.53,-11.58]
e1 = [195.33,195.33]
f1 = [195.38,195.38]

a2 = [195.38,195.43]
b2 = [-11.66,-11.66]
c2 = [-11.61,-11.61]
d2 = [-11.66,-11.61]
e2 = [195.38,195.38]
f2 = [195.43,195.43]

a3 = [195.39,195.44]
b3 = [-11.72,-11.72]
c3 = [-11.67,-11.67]
d3 = [-11.72,-11.67]
e3 = [195.39,195.39]
f3 = [195.44,195.44]

circle1 = plt.Circle((195.4, -11.65), 0.05, color='r', fill=False)


sns.kdeplot(ra, dec, cmap="Blues", shade=True, shade_lowest=True)
plt.gcf().gca().add_artist(circle1)


plt.plot(a,c,color='black')
plt.plot(a,b,color='black')
plt.plot(e,d,color='black')
plt.plot(f,d,color='black')
plt.plot(a1,c1,color='black')
plt.plot(a1,b1,color='black')
plt.plot(e1,d1,color='black')
plt.plot(f1,d1,color='black')
plt.plot(a2,c2,color='black')
plt.plot(a2,b2,color='black')
plt.plot(e2,d2,color='black')
plt.plot(f2,d2,color='black')
plt.plot(a3,c3,color='black')
plt.plot(a3,b3,color='black')
plt.plot(e3,d3,color='black')
plt.plot(f3,d3,color='black')
plt.title('1301')
plt.xlim(195.1,195.7)
#plt.ylim(-11.9,-11.3)
plt.subplot(3,2,4)

f = open('/Users/jennifercooper/Projects/thesis/WFI_catalogs/1059.txt', 'r')
lines = f.readlines()[1:]
f.close()
    
#create arrays 
ra    = [] 
dec   = []

  
    
    #pull array column 
for line in lines: 
    a = line.split()
    ra.append(float(a[0]))
    dec.append(float(a[1]))

a = [164.63,164.68]
b = [-12.91,-12.91]
c = [-12.86,-12.86]
d = [-12.91,-12.86]
e = [164.63,164.63]
f = [164.68,164.68]

a1 = [164.77,164.82]
b1 = [-12.93,-12.93]
c1 = [-12.88,-12.88]
d1 = [-12.93,-12.88]
e1 = [164.77,164.77]
f1 = [164.82,164.82]

a2 = [164.71,164.76]
b2 = [-12.9,-12.9]
c2 = [-12.85,-12.85]
d2 = [-12.85,-12.9]
e2 = [164.71,164.71]
f2 = [164.76,164.76]

a3 = [164.75,164.8]
b3 = [-12.79,-12.79]
c3 = [-12.74,-12.74]
d3 = [-12.79,-12.74]
e3 = [164.75,164.75]
f3 = [164.8,164.8]    
        
ra = np.array(ra)
dec = np.array(dec)

circle1 = plt.Circle((164.8, -12.9), 0.05, color='r', fill=False)
sns.kdeplot(ra, dec, cmap="Blues", shade=True, shade_lowest=True)
plt.gcf().gca().add_artist(circle1)
plt.plot(a,c,color='black')
plt.plot(a,b,color='black')
plt.plot(e,d,color='black')
plt.plot(f,d,color='black')
plt.plot(a1,c1,color='black')
plt.plot(a1,b1,color='black')
plt.plot(e1,d1,color='black')
plt.plot(f1,d1,color='black')
plt.plot(a2,c2,color='black')
plt.plot(a2,b2,color='black')
plt.plot(e2,d2,color='black')
plt.plot(f2,d2,color='black')
plt.plot(a3,c3,color='black')
plt.plot(a3,b3,color='black')
plt.plot(e3,d3,color='black')
plt.plot(f3,d3,color='black')
plt.title('1059')
plt.show()
